# %%
# !pip install pyrebase
import pyrebase

# %%
firebaseConfig = {

  'apiKey': "AIzaSyDkNkJ63_z4Gg8BVbsQiU0Q9xhv2NX6zHc",
  'authDomain': "daas-f3ad5.firebaseapp.com",
  'projectId': "daas-f3ad5",
  'storageBucket': "daas-f3ad5.appspot.com",
  'messagingSenderId': "374678880828",
  'appId': "1:374678880828:web:941c27e86d1f632066b939",
  'measurementId': "G-PCC0C9X16N",
  'databaseURL':"https://daas-f3ad5-default-rtdb.firebaseio.com/"

};

# %%
firebase = pyrebase.initialize_app(firebaseConfig)

# %%
db = firebase.database()

# %% [markdown]
# INSERT DATA

# %%
data = {
'date': "01/04/2022",
'description': "36 hrs hackathon",
'domain': "Web Development",
'locationlink': "https://goo.gl/maps/RAmpWPKK7oFki9sK7",
'name': "hackathon"
}

# %%
db.child("Events").set(data)
# Out:
# {'date': '01/04/2022',
#  'description': '36 hrs hackathon',
#  'domain': 'Web Development',
#  'locationlink': 'https://goo.gl/maps/RAmpWPKK7oFki9sK7',
#  'name': 'hackathon'}

# %%
d = [{
'date': "01/04/2022",
'description': "36 hrs hackathon",
'domain': "Web Development",
'locationlink': "https://goo.gl/maps/RAmpWPKK7oFki9sK7",
'name': "hackathon"
},
{
'date': "11/04/2022",
'description': "cloudathon",
'domain': "Cloud",
'locationlink': "https://goo.gl/maps/RAmpWPKK7oFki9sK7",
'name': "Cloudathon"
}]

# %%
db.child("Events").set(d)
# Out:
# [{'date': '01/04/2022',
#   'description': '36 hrs hackathon',
#   'domain': 'Web Development',
#   'locationlink': 'https://goo.gl/maps/RAmpWPKK7oFki9sK7',
#   'name': 'hackathon'},
#  {'date': '11/04/2022',
#   'description': 'cloudathon',
#   'domain': 'Cloud',
#   'locationlink': 'https://goo.gl/maps/RAmpWPKK7oFki9sK7',
#   'name': 'Cloudathon'}]

# %% [markdown]
# UPDATE DATA

# %%
db.child("Events").update({'name':'Hackathon'})
# Out:
# {'name': 'Hackathon'}

# %% [markdown]
# DELETE DATA

# %%
db.child("Events").child("domain").remove()

# %% [markdown]
# RETRIEVE DATA

# %%
d = db.get()

# %%
d.val()
# Out:
# OrderedDict([('Events',
#               {'0': {'date': '01/04/2022',
#                 'description': '36 hrs hackathon',
#                 'domain': 'Web Development',
#                 'locationlink': 'https://goo.gl/maps/RAmpWPKK7oFki9sK7',
#                 'name': 'hackathon'},
#                '1': {'date': '11/04/2022',
#                 'description': 'cloudathon',
#                 'domain': 'Cloud',
#                 'locationlink': 'https://goo.gl/maps/RAmpWPKK7oFki9sK7',
#                 'name': 'Cloudathon'},
#                'name': 'Hackathon'})])

# %%
x = db.child('Events').get()

# %%
d.val()
# Out:
# OrderedDict([('Events',
#               {'0': {'date': '01/04/2022',
#                 'description': '36 hrs hackathon',
#                 'domain': 'Web Development',
#                 'locationlink': 'https://goo.gl/maps/RAmpWPKK7oFki9sK7',
#                 'name': 'hackathon'},
#                '1': {'date': '11/04/2022',
#                 'description': 'cloudathon',
#                 'domain': 'Cloud',
#                 'locationlink': 'https://goo.gl/maps/RAmpWPKK7oFki9sK7',
#                 'name': 'Cloudathon'},
#                'name': 'Hackathon'})])
